# %%
import random
from pathlib import Path

import pandas as pd

from utils.plots import (
    plot_monthly_water,
    plot_tif,
    plot_water_over_time,
    plot_water_x_cloud_percent,
    plot_water_x_cloud_percent_filter,
    plot_water_x_cloud_percent_over_time,
    plot_year_x_variable,
)
from utils.water import calculate_water_area

# %%
area_data = pd.read_csv("./data/areas.csv")

# %%
area_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   m2_area_fmask_deepwatermap   477 non-null    float64
#  1   km2_area_fmask_deepwatermap  477 non-null    float64
#  2   m2_area_deepwatermap         480 non-null    float64
#  3   km2_area_deepwatermap        480 non-null    float64
#  4   km2_area_ndwi                480 non-null    float64
#  5   m2_area_fmask_ndwi           477 non-null    float64
#  6   km2_area_fmask_ndwi          477 non-null    float64
#  7   m2_area_mndwi                480 non-null    float64
#  8   km2_area_mndwi               480 non-null    float64
#  9   m2_area_fmask_mndwi          477 non-null    float64
#  10  km2_area_fmask_mndwi         477 non-null    float64
#  11  year                         480 non-null    int64
# ...

# %%
plot_water_over_time(
    area_data,
    y_variables=['m2_area_deepwatermap', 'm2_area_ndwi', 'm2_area_mndwi'],
    labels=['DeepWaterMap', 'NDWI', 'MNDWI'],
    title="Área de água ao longo do tempo - sem remoção de nuvens"
)

# %%
plot_water_over_time(
    area_data,
    y_variables=['m2_area_fmask_deepwatermap', 'm2_area_fmask_ndwi', 'm2_area_fmask_mndwi'],
    labels=['DeepWaterMap', 'NDWI', 'MNDWI'],
    title="Área de água ao longo do tempo - com remoção de nuvens"
)
