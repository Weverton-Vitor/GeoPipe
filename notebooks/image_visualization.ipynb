# %%
import os
import glob
import numpy as np
from logging import getLogger  
from tqdm import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
import tifffile as tiff
# Out:
# WARNING:tensorflow:From c:\Users\weverton.vitor\Documents\faculdade\pibic\fmask-pipeline\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# ler imagem e plotar
img = 'C:/Users/weverton.vitor/Documents/faculdade/pibic/fmask-pipeline/data/04_clean_images/lagoa_do_arroz_reservatorio/2021/sentinel_6B_BOA_S2_SR_lagoa_do_arroz_reservatorio_20210113_clean.tif'
image = tiff.imread(img)
plt.imshow(image[:, :, [3, 2, 1]] /10000)

# %%
# ler imagem e plotar
img = 'C:/Users/weverton.vitor/Documents/faculdade/pibic/fmask-pipeline/data/09_spectral_indice/NDWI/sume_reservatorio_ndwi_fmask/2021/sentinel_6B_BOA_S2_SR_sume_reservatorio_20210420_clean.tif'
image = tiff.imread(img)
print(np.max(image))
print(np.min(image))
print(len(np.unique(image)))
plt.imshow(image<1, cmap='gray')
# Out:
# 1.0
# -0.7612193
# 140523

# %%
# ler imagem e plotar
img = 'C:/Users/weverton.vitor/Documents/faculdade/pibic/fmask-pipeline/data/09_spectral_indice/NDWI/sume_reservatorio/2021/sentinel_6B_BOA_S2_SR_sume_reservatorio_20210420.tif'
image = tiff.imread(img)
print(np.max(image))
print(np.min(image))
print(len(np.unique(image)))
plt.imshow(image, cmap='gray')
# Out:
# 0.7091837
# -0.7612193
# 234138
